# %% [markdown]
# # FEATURE ENGINEERING
# In this section we will create new features useful for further predictions.

# %%
import pandas as pd
import numpy as np
import lightgbm as lgb
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
pd.options.display.max_columns = 250
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# First of all, we have to load our data and sort it by normalized arrival time. That will facilitate aggregating data with just finished flights.

# %%
data = pd.read_pickle('data.pkl')
data.sort_values('ARRIVAL_TIME_NORMALIZED',  inplace = True)
data.reset_index(drop = True, inplace = True)

# %%
data.head()
# Out:
#    MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER ORIGIN_AIRPORT  \
# 0      1    1            4      NK            451      N633NK            PBG
# 1      1    1            4      B6            668      N653JB            PSE
# 2      1    1            4      NK            647      N630NK            IAG
# 3      1    1            4      DL           2336      N958DN            DEN
# 4      1    1            4      UA           1528      N76519            SJU
#
#   DESTINATION_AIRPORT SCHEDULED_DEPARTURE      DEPARTURE_TIME  \
# 0                 FLL 2015-01-01 01:55:00 2015-01-01 01:39:00
# 1                 MCO 2015-01-01 02:55:00 2015-01-01 02:48:00
# 2                 FLL 2015-01-01 02:00:00 2015-01-01 01:55:00
# 3                 ATL 2015-01-01 00:30:00 2015-01-01 00:24:00
# 4                 EWR 2015-01-01 01:54:00 2015-01-01 01:57:00
#
#    DEPARTURE_DELAY  TAXI_OUT  WHEELS_OFF  SCHEDULED_TIME  ELAPSED_TIME  \
# 0            -16.0      10.0       149.0           208.0         191.0
# 1             -7.0      10.0       258.0           185.0         183.0
# 2             -5.0      21.0       216.0           184.0         178.0
# 3             -6.0      12.0        36.0           173.0         149.0
# 4              3.0      12.0       209.0           255.0         241.0
#
#    AIR_TIME  DISTANCE  WHEELS_ON  TAXI_IN  SCHEDULED_ARRIVAL  ARRIVAL_DELAY  \
# 0     174.0      1334      443.0      7.0                523          -33.0
# 1     169.0      1179      447.0      4.0                500           -9.0
# 2     149.0      1176      445.0      8.0                504          -11.0
# 3     133.0      1199      449.0      4.0                523          -30.0
# 4     220.0      1608      449.0      9.0                509          -11.0
#
#    AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  LATE_AIRCRAFT_DELAY  \
# 0               NaN             NaN            NaN                  NaN
# 1               NaN             NaN            NaN                  NaN
# 2               NaN             NaN            NaN                  NaN
# 3               NaN             NaN            NaN                  NaN
# 4               NaN             NaN            NaN                  NaN
#
#    WEATHER_DELAY STATE_ORIGIN  LATITUDE_ORIGIN  LONGITUDE_ORIGIN  \
# 0            NaN           NY         44.69282         -73.45562
# 1            NaN           PR         18.00830         -66.56301
# 2            NaN           NY         43.10726         -78.94538
# 3            NaN           CO         39.85841        -104.66700
# 4            NaN           PR         18.43942         -66.00183
#
#   STATE_DESTINATION  LATITUDE_DESTINATION  LONGITUDE_DESTINATION  \
# 0                FL              26.07258              -80.15275
# 1                FL              28.42889              -81.31603
# 2                FL              26.07258              -80.15275
# 3                GA              33.64044              -84.42694
# 4                NJ              40.69250              -74.16866
#
#    SCHEDULED_DEPARTURE_HH  DEPARTURE_TIME_HH  SCHEDULED_ARRIVAL_HH  \
# 0                       1                  1                     5
# 1                       2                  2                     5
# 2                       2                  1                     5
# 3                       0                  0                     5
# 4                       1                  1                     5
#
#    WHEELS_OFF_HH  ARRIVAL_TIME_HH        ARRIVAL_TIME  \
# 0              1                4 2015-01-01 04:50:00
# 1              2                4 2015-01-01 04:51:00
# 2              2                4 2015-01-01 04:53:00
# 3              0                4 2015-01-01 04:53:00
# 4              2                4 2015-01-01 04:58:00
#
#   DEPARTURE_TIME_NORMALIZED ARRIVAL_TIME_NORMALIZED    ROUTE ROUTE_STATES
# 0       2015-01-01 06:39:00     2015-01-01 09:50:00  PBG_FLL        NY_FL
# 1       2015-01-01 06:48:00     2015-01-01 09:51:00  PSE_MCO        PR_FL
# 2       2015-01-01 06:55:00     2015-01-01 09:53:00  IAG_FLL        NY_FL
# 3       2015-01-01 07:24:00     2015-01-01 09:53:00  DEN_ATL        CO_GA
# 4       2015-01-01 05:57:00     2015-01-01 09:58:00  SJU_EWR        PR_NJ

# %% [markdown]
# Let's start off creating new features by creating DELAY_REDUCTION, AIRLINE + ROUTE and AIRLINE + FLIGHT_NUMBER + ROUTE based on already existing columns.
# * DELAY_REDUCTION is a difference between departure delay and arrival delay.
# * AIRLINE_ROUTE enables us to distinguish arrival delay on a particular route by different airlines.
# * AIRLINE_FLIGHT_NUMBER_ROUTE can identify particular repetitive flights.

# %%
data['DELAY_REDUCTION'] = data.DEPARTURE_DELAY - data.ARRIVAL_DELAY
data['AIRLINE_ROUTE'] = data.AIRLINE + '_' + data.ROUTE
data['AIRLINE_FLIGHT_NUMBER_ROUTE'] = data.AIRLINE + '_' + data.FLIGHT_NUMBER.astype('str') + '_' + data.ROUTE

# %% [markdown]
# The predictions will be made for the flights with a given departure delay. Due to the fact that departure delay in most cases is clearly correlated with arrival delay, we will be creating new features based on values of delay reduction. It is more informative than arrival delay itself. The purpose of the other variables will be to improve the difference between departure and arrival delay.
#
# We will create new features based on different approaches:
# * Mean of delay reduction for flights that arrived in last 1/5/24 hours grouped by various columns. Delay reduction by certain features from last flights should be really helpful in estimating expected arrival delay.
# * Mean of taxi out/taxi for flights that arrived in last 1/5/24 hours grouped by origin airport/destination airport. We want to use only those columns that make sense in such use. Taxi out is a measurement of the time between departure from the origin airport gate and the moment when an airline takes off so the results grouped by origin airport should be the best indicator of expected taxi out. We will also check whether particular repetitive flights could have an influence on that. Similar approach is used for taxi in which is grouped by destination airport and particular flights.
# * Mean of delay reduction based on various features on the whole train set. We can suspect based on former flights that the situation in the new flights could be similar.
# * Mean of previous 1/3/7 flights based on features that ensure that there can't be any flight that starts before the arrival of a different flight from particular group. We can base only on flights that have already finished.
# * A percentage of flights with increased delay reduction grouped by various columns on the whole train set. It can provide information whether we should expect an increase or decrease in delay in the new flights.
# * Differences between average delay reduction from last 1/5/24 hours or for last 1/3/7 flights and the mean on the whole train set. It will provide us with information on how different from average are the last results.

# %% [markdown]
# The first step, features based on last 1/5/24 hours, can be performed on the full data set so we don't have to split data into train and test set yet.

# %%
hours_vals = [1, 5, 24]
def delay_by_periods(data, col, col_agg = 'DELAY_REDUCTION'):
    for hours in hours_vals:
        data[col + '_' + col_agg + '_' + str(hours) + '_HOURS_MEAN'] = np.nan
    for col_val in data[col].unique():
        data_frac = data[data[col] == col_val]
        for i in range(len(data_frac)):
            for hours in hours_vals:
                delays = data_frac.loc[(data_frac.DEPARTURE_TIME_NORMALIZED.iloc[i] > data_frac.ARRIVAL_TIME_NORMALIZED) &
                        (data_frac.ARRIVAL_TIME_NORMALIZED > (data_frac.DEPARTURE_TIME_NORMALIZED.iloc[i] - pd.Timedelta(hours = hours))),
                        col_agg]
                data[col + '_' + col_agg + '_' + str(hours) + '_HOURS_MEAN'].iloc[data_frac.index[i]] = delays.mean()
    return data

# %%
cols_to_agg = ['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'AIRLINE', 'ROUTE_STATES', 'ROUTE', 'TAIL_NUMBER', 'AIRLINE_ROUTE']

for col in cols_to_agg:
    data = delay_by_periods(data, col)
    
data = delay_by_periods(data, 'ORIGIN_AIRPORT', 'TAXI_OUT')
data = delay_by_periods(data, 'DESTINATION_AIRPORT', 'TAXI_IN')

# %% [markdown]
# Let's also create average departure delay from last 24 hours grouped by AIRLINE_FLIGHT_NUMBER_ROUTE. It doesn't make sense to create variables also by 1-hour and 5-hours intervals because the same flights take place only once a day.

# %%
hours_vals = [24]

data = delay_by_periods(data, 'AIRLINE_FLIGHT_NUMBER_ROUTE')

# %% [markdown]
# For next steps we have to divide our data into train and test set.
# The train set will include data from January to March, leaving April for the test set.

# %%
train = data[data.MONTH <= 3]
test = data[data.MONTH == 4].reset_index(drop = True)
del data

# %%
def aggregates_on_delay(data, col, aggregate = 'mean', col_agg = 'DELAY_REDUCTION'):
    aggregate = train.groupby(col)[col_agg].agg([aggregate])\
                        .rename({aggregate: col + '_' + col_agg + '_' + aggregate.upper()}, axis = 1)
    data = pd.merge(data, aggregate, on = col, how = 'left')
    return data

# %%
cols_to_agg_delay_reduction = ['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'AIRLINE', 'ROUTE_STATES', 'ROUTE', 'TAIL_NUMBER', 
               'SCHEDULED_DEPARTURE_HH', 'SCHEDULED_ARRIVAL_HH', 'AIRLINE_ROUTE', 'AIRLINE_FLIGHT_NUMBER_ROUTE']

cols_to_agg_taxi_out = ['ORIGIN_AIRPORT', 'AIRLINE_FLIGHT_NUMBER_ROUTE']
cols_to_agg_taxi_in = ['DESTINATION_AIRPORT', 'AIRLINE_FLIGHT_NUMBER_ROUTE']

for col in cols_to_agg_delay_reduction:
    train = aggregates_on_delay(train, col, 'mean')
    test = aggregates_on_delay(test, col, 'mean')

for col in cols_to_agg_taxi_out: 
    train = aggregates_on_delay(train, col, 'mean', 'TAXI_OUT')
    test = aggregates_on_delay(test, col, 'mean', 'TAXI_OUT')        
    
for col in cols_to_agg_taxi_in: 
    train = aggregates_on_delay(train, col, 'mean', 'TAXI_IN')
    test = aggregates_on_delay(test, col, 'mean', 'TAXI_IN')

# %% [markdown]
# For a percentage of increased delay function we will set a minimum number of required previous values to 10. It will prevent us from situations where for a very small number of observations the vast majority of values have an increased delay, whereas on the whole the delay seems to decrease. A sample can't be too small to obtain reliable results.

# %%
def perc_of_increased_delay(data, col, min_n = 10):
    train_delayed = train.loc[train.DELAY_REDUCTION < 0, ['DELAY_REDUCTION', col]]
    if len(train_delayed) >= min_n:
        aggregate = ((train_delayed.groupby(col).count() / train[['DELAY_REDUCTION', col]].groupby(col).count())).\
        rename({'DELAY_REDUCTION': 'PERC_OF_INCREASED_DEL_' + col}, axis = 1)
    data = pd.merge(data, aggregate, on = col, how = 'left')
    return data

# %%
cols_to_agg_perc = ['ORIGIN_AIRPORT', 'DESTINATION_AIRPORT', 'AIRLINE', 'ROUTE_STATES', 'ROUTE', 'TAIL_NUMBER',
                    'AIRLINE_ROUTE', 'SCHEDULED_DEPARTURE_HH', 'SCHEDULED_ARRIVAL_HH', 'AIRLINE_FLIGHT_NUMBER_ROUTE']

for col in cols_to_agg_perc:
    train = perc_of_increased_delay(train, col)
    test = perc_of_increased_delay(test, col)

# %% [markdown]
# The individual flights can be obtained from AIRLINE_FLIGHT_NUMBER_ROUTE and TAIL_NUMBER variables.

# %%
def rolling_previous(train_set, test_set, col, n, aggregate = 'mean', col_agg = 'DELAY_REDUCTION'):
    data = pd.concat([train_set, test_set], axis = 0).reset_index(drop = True)
    data[col + '_' + col_agg + '_ROLLING_' + str(n) + '_' + aggregate.upper()] =\
        data.groupby(col)[col_agg].transform(lambda x: x.shift(1).rolling(n, n).agg(aggregate))
    train_set = data[data.MONTH <= 3]
    test_set = data[data.MONTH == 4].reset_index(drop = True)
    return train_set, test_set

# %%
for n in [1, 3, 7]:
    train, test = rolling_previous(train, test, col = 'AIRLINE_FLIGHT_NUMBER_ROUTE', n = n)
    train, test = rolling_previous(train, test, col = 'AIRLINE_FLIGHT_NUMBER_ROUTE', n = n, col_agg = 'TAXI_IN')
    train, test = rolling_previous(train, test, col = 'AIRLINE_FLIGHT_NUMBER_ROUTE', n = n, col_agg = 'TAXI_OUT')
    train, test = rolling_previous(train, test, col = 'TAIL_NUMBER', n = n)

# %% [markdown]
# The next step includes differences between means of delay_reduction/taxi_in/taxi_out from some period and on the whole. After that, we will no longer need means on the whole. The information from those variables will be already included in variables from some periods and the differences.

# %%
for hour in [1, 5, 24]:
    for col in train.columns[(train.columns.str.contains(str(hour) + '_HOURS')) & (train.columns.str.contains('DELAY'))]:
        train[col + '_DIFF'] = train[col] - train[col.replace(str(hour) + '_HOURS_', '')]
        test[col + '_DIFF'] = test[col] - test[col.replace(str(hour) + '_HOURS_', '')]
        
    for col in train.columns[(train.columns.str.contains(str(hour) + '_HOURS')) & (train.columns.str.contains('TAXI_IN'))]:
        train[col + '_DIFF'] = train[col] - train[col.replace(str(hour) + '_HOURS_', '')]
        test[col + '_DIFF'] = test[col] - test[col.replace(str(hour) + '_HOURS_', '')]
    
    for col in train.columns[(train.columns.str.contains(str(hour) + '_HOURS')) & (train.columns.str.contains('TAXI_OUT'))]:
        train[col + '_DIFF'] = train[col] - train[col.replace(str(hour) + '_HOURS_', '')]
        test[col + '_DIFF'] = test[col] - test[col.replace(str(hour) + '_HOURS_', '')]

# %%
for previous in [1, 3, 7]:
    for col in train.columns[(train.columns.str.contains('ROLLING_' + str(previous)))]:
        train[col + '_DIFF'] = train[col] - train[col.replace('_ROLLING_' + str(previous) , '')]
        test[col + '_DIFF'] = test[col] - test[col.replace('_ROLLING_' + str(previous), '')]

# %%
train.drop(['ORIGIN_AIRPORT_DELAY_REDUCTION_MEAN',
       'DESTINATION_AIRPORT_DELAY_REDUCTION_MEAN',
       'AIRLINE_DELAY_REDUCTION_MEAN', 'ROUTE_STATES_DELAY_REDUCTION_MEAN',
       'ROUTE_DELAY_REDUCTION_MEAN', 'TAIL_NUMBER_DELAY_REDUCTION_MEAN',
       'SCHEDULED_DEPARTURE_HH_DELAY_REDUCTION_MEAN',
       'SCHEDULED_ARRIVAL_HH_DELAY_REDUCTION_MEAN',
       'AIRLINE_ROUTE_DELAY_REDUCTION_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_MEAN',
       'ORIGIN_AIRPORT_TAXI_OUT_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_MEAN',
       'DESTINATION_AIRPORT_TAXI_IN_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_MEAN'], axis = 1, inplace = True)

test.drop(['ORIGIN_AIRPORT_DELAY_REDUCTION_MEAN',
       'DESTINATION_AIRPORT_DELAY_REDUCTION_MEAN',
       'AIRLINE_DELAY_REDUCTION_MEAN', 'ROUTE_STATES_DELAY_REDUCTION_MEAN',
       'ROUTE_DELAY_REDUCTION_MEAN', 'TAIL_NUMBER_DELAY_REDUCTION_MEAN',
       'SCHEDULED_DEPARTURE_HH_DELAY_REDUCTION_MEAN',
       'SCHEDULED_ARRIVAL_HH_DELAY_REDUCTION_MEAN',
       'AIRLINE_ROUTE_DELAY_REDUCTION_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_MEAN',
       'ORIGIN_AIRPORT_TAXI_OUT_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_MEAN',
       'DESTINATION_AIRPORT_TAXI_IN_MEAN',
       'AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_MEAN'], axis = 1, inplace = True)

# %% [markdown]
# Let's also drop other variables that won't be used in models' creation.

# %%
train.drop(['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'TAXI_OUT', 'WHEELS_OFF',
                    'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL',
                    'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 
                    'WEATHER_DELAY', 'DEPARTURE_TIME_HH', 'WHEELS_OFF_HH', 'ARRIVAL_TIME_HH',
                    'ARRIVAL_TIME', 'DEPARTURE_TIME_NORMALIZED', 'ARRIVAL_TIME_NORMALIZED', 'DELAY_REDUCTION',
                    'FLIGHT_NUMBER'], axis = 1, inplace = True)

test.drop(['MONTH', 'DAY', 'SCHEDULED_DEPARTURE', 'DEPARTURE_TIME', 'TAXI_OUT', 'WHEELS_OFF',
                    'SCHEDULED_TIME', 'ELAPSED_TIME', 'AIR_TIME', 'WHEELS_ON', 'TAXI_IN', 'SCHEDULED_ARRIVAL',
                    'AIR_SYSTEM_DELAY', 'SECURITY_DELAY', 'AIRLINE_DELAY', 'LATE_AIRCRAFT_DELAY', 
                    'WEATHER_DELAY', 'DEPARTURE_TIME_HH', 'WHEELS_OFF_HH', 'ARRIVAL_TIME_HH',
                    'ARRIVAL_TIME', 'DEPARTURE_TIME_NORMALIZED', 'ARRIVAL_TIME_NORMALIZED', 'DELAY_REDUCTION',
                    'FLIGHT_NUMBER'], axis = 1, inplace = True)

# %%
print('Shape of the train set:', train.shape)
print('Shape of the test set:', test.shape)
# Out:
# Shape of the train set: (1356814, 110)
# Shape of the test set: (479251, 110)

# %%
train.head()
# Out:
#    DAY_OF_WEEK AIRLINE TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0            4      NK      N633NK            PBG                 FLL
# 1            4      B6      N653JB            PSE                 MCO
# 2            4      DL      N958DN            DEN                 ATL
# 3            4      NK      N630NK            IAG                 FLL
# 4            4      UA      N76519            SJU                 EWR
#
#    DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY STATE_ORIGIN  LATITUDE_ORIGIN  \
# 0            -16.0      1334          -33.0           NY         44.69282
# 1             -7.0      1179           -9.0           PR         18.00830
# 2             -6.0      1199          -30.0           CO         39.85841
# 3             -5.0      1176          -11.0           NY         43.10726
# 4              3.0      1608          -11.0           PR         18.43942
#
#    LONGITUDE_ORIGIN STATE_DESTINATION  LATITUDE_DESTINATION  \
# 0         -73.45562                FL              26.07258
# 1         -66.56301                FL              28.42889
# 2        -104.66700                GA              33.64044
# 3         -78.94538                FL              26.07258
# 4         -66.00183                NJ              40.69250
#
#    LONGITUDE_DESTINATION  SCHEDULED_DEPARTURE_HH  SCHEDULED_ARRIVAL_HH  \
# 0              -80.15275                       1                     5
# 1              -81.31603                       2                     5
# 2              -84.42694                       0                     5
# 3              -80.15275                       2                     5
# 4              -74.16866                       1                     5
#
#      ROUTE ROUTE_STATES  ORIGIN_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0  PBG_FLL        NY_FL                                          NaN
# 1  PSE_MCO        PR_FL                                          NaN
# 2  DEN_ATL        CO_GA                                          NaN
# 3  IAG_FLL        NY_FL                                          NaN
# 4  SJU_EWR        PR_NJ                                          NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    AIRLINE_DELAY_REDUCTION_1_HOURS_MEAN  AIRLINE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ROUTE_DELAY_REDUCTION_1_HOURS_MEAN  ROUTE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                 NaN                                 NaN
# 1                                 NaN                                 NaN
# 2                                 NaN                                 NaN
# 3                                 NaN                                 NaN
# 4                                 NaN                                 NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_24_HOURS_MEAN AIRLINE_ROUTE  \
# 0                                        NaN    NK_PBG_FLL
# 1                                        NaN    B6_PSE_MCO
# 2                                        NaN    DL_DEN_ATL
# 3                                        NaN    NK_IAG_FLL
# 4                                        NaN    UA_SJU_EWR
#
#   AIRLINE_FLIGHT_NUMBER_ROUTE  AIRLINE_ROUTE_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0              NK_451_PBG_FLL                                         NaN
# 1              B6_668_PSE_MCO                                         NaN
# 2             DL_2336_DEN_ATL                                         NaN
# 3              NK_647_IAG_FLL                                         NaN
# 4             UA_1528_SJU_EWR                                         NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_1_HOURS_MEAN  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_5_HOURS_MEAN  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_24_HOURS_MEAN  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    PERC_OF_INCREASED_DEL_ORIGIN_AIRPORT  \
# 0                              0.356322
# 1                              0.385027
# 2                              0.275941
# 3                              0.375000
# 4                              0.307278
#
#    PERC_OF_INCREASED_DEL_DESTINATION_AIRPORT  PERC_OF_INCREASED_DEL_AIRLINE  \
# 0                                   0.258135                       0.363750
# 1                                   0.275322                       0.336859
# 2                                   0.254317                       0.222840
# 3                                   0.258135                       0.363750
# 4                                   0.279543                       0.216393
#
#    PERC_OF_INCREASED_DEL_ROUTE_STATES  PERC_OF_INCREASED_DEL_ROUTE  \
# 0                            0.308834                     0.356322
# 1                            0.299888                     0.382353
# 2                            0.209451                     0.212521
# 3                            0.308834                     0.365854
# 4                            0.301408                     0.300341
#
#    PERC_OF_INCREASED_DEL_TAIL_NUMBER  \
# 0                           0.372500
# 1                           0.378981
# 2                           0.217507
# 3                           0.395577
# 4                           0.205021
#
#    PERC_OF_INCREASED_DEL_SCHEDULED_DEPARTURE_HH  \
# 0                                      0.377837
# 1                                      0.377301
# 2                                      0.346747
# 3                                      0.377301
# 4                                      0.377837
#
#    PERC_OF_INCREASED_DEL_SCHEDULED_ARRIVAL_HH  \
# 0                                    0.304152
# 1                                    0.304152
# 2                                    0.304152
# 3                                    0.304152
# 4                                    0.304152
#
#    PERC_OF_INCREASED_DEL_AIRLINE_ROUTE  \
# 0                             0.356322
# 1                             0.382353
# 2                             0.173841
# 3                             0.365854
# 4                             0.307692
#
#    PERC_OF_INCREASED_DEL_AIRLINE_FLIGHT_NUMBER_ROUTE  \
# 0                                           0.356322
# 1                                           0.416667
# 2                                                NaN
# 3                                           0.365854
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_1_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_3_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_7_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_1_HOURS_MEAN  ORIGIN_AIRPORT_TAXI_OUT_5_HOURS_MEAN  \
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_24_HOURS_MEAN  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_1_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_3_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_7_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_1_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_3_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_7_MEAN  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_1_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_3_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_7_MEAN  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ROUTE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_1_HOURS_MEAN_DIFF  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_1_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ROUTE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_5_HOURS_MEAN_DIFF  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_5_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    ROUTE_STATES_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_24_HOURS_MEAN_DIFF  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_24_HOURS_MEAN_DIFF  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_1_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_1_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_1_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_1_MEAN_DIFF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_3_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_3_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_3_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_3_MEAN_DIFF  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_7_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_7_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_7_MEAN_DIFF  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_7_MEAN_DIFF
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN

# %%
test.head()
# Out:
#    DAY_OF_WEEK AIRLINE TAIL_NUMBER ORIGIN_AIRPORT DESTINATION_AIRPORT  \
# 0            3      NK      N613NK            IAG                 FLL
# 1            3      B6      N665JB            SJU                 JFK
# 2            3      UA      N37273            SJU                 EWR
# 3            3      DL      N557NW            DEN                 ATL
# 4            3      NK      N624NK            PBG                 FLL
#
#    DEPARTURE_DELAY  DISTANCE  ARRIVAL_DELAY STATE_ORIGIN  LATITUDE_ORIGIN  \
# 0            -12.0      1176          -31.0           NY         43.10726
# 1             -4.0      1598          -20.0           PR         18.43942
# 2              6.0      1608          -13.0           PR         18.43942
# 3             -8.0      1199          -11.0           CO         39.85841
# 4            -12.0      1334          -20.0           NY         44.69282
#
#    LONGITUDE_ORIGIN STATE_DESTINATION  LATITUDE_DESTINATION  \
# 0         -78.94538                FL              26.07258
# 1         -66.00183                NY              40.63975
# 2         -66.00183                NJ              40.69250
# 3        -104.66700                GA              33.64044
# 4         -73.45562                FL              26.07258
#
#    LONGITUDE_DESTINATION  SCHEDULED_DEPARTURE_HH  SCHEDULED_ARRIVAL_HH  \
# 0              -80.15275                       2                     5
# 1              -73.77893                       1                     5
# 2              -74.16866                       0                     5
# 3              -84.42694                       0                     5
# 4              -80.15275                       1                     5
#
#      ROUTE ROUTE_STATES  ORIGIN_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0  IAG_FLL        NY_FL                                          NaN
# 1  SJU_JFK        PR_NY                                    15.500000
# 2  SJU_EWR        PR_NJ                                    15.500000
# 3  DEN_ATL        CO_GA                                     0.636364
# 4  PBG_FLL        NY_FL                                          NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                          NaN
# 1                                    -3.000000
# 2                                    -3.000000
# 3                                     5.595092
# 4                                          NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                         19.333333
# 1                                          3.454545
# 2                                          6.400000
# 3                                               NaN
# 4                                         18.500000
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                         12.357143
# 1                                          6.528571
# 2                                         -4.388235
# 3                                          2.488372
# 4                                         12.189655
#
#    AIRLINE_DELAY_REDUCTION_1_HOURS_MEAN  AIRLINE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                              3.416667                              4.278481
# 1                             10.642857                              7.301676
# 2                             10.453125                              8.039062
# 3                              1.896552                              3.900862
# 4                              2.538462                              3.853659
#
#    ROUTE_STATES_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                  19.333333
# 1                                  15.500000
# 2                                        NaN
# 3                                        NaN
# 4                                  18.500000
#
#    ROUTE_STATES_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                  16.735294
# 1                                   5.500000
# 2                                 -11.500000
# 3                                   6.500000
# 4                                  16.333333
#
#    ROUTE_DELAY_REDUCTION_1_HOURS_MEAN  ROUTE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                 NaN                                 NaN
# 1                                15.5                                 5.5
# 2                                 NaN                               -11.5
# 3                                 NaN                                 6.5
# 4                                 NaN                                 NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0                                      -8.0
# 1                                       NaN
# 2                                      15.0
# 3                                       NaN
# 4                                       0.0
#
#    TAIL_NUMBER_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                      -8.0
# 1                                      14.0
# 2                                      15.0
# 3                                       4.0
# 4                                       1.0
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                     16.000000
# 1                                      1.253521
# 2                                      1.444444
# 3                                      6.940778
# 4                                     18.000000
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                          14.430279
# 1                                           5.842105
# 2                                           2.128440
# 3                                           8.227695
# 4                                          14.404000
#
#    AIRLINE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                               3.696667
# 1                               7.356952
# 2                               9.215837
# 3                               6.922259
# 4                               3.647841
#
#    ROUTE_STATES_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                   16.335079
# 1                                   14.294118
# 2                                    5.000000
# 3                                    8.000000
# 4                                   16.310526
#
#    ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                            16.000000
# 1                            13.666667
# 2                             2.000000
# 3                             7.588235
# 4                            18.000000
#
#    TAIL_NUMBER_DELAY_REDUCTION_24_HOURS_MEAN AIRLINE_ROUTE  \
# 0                                   2.500000    NK_IAG_FLL
# 1                                   6.500000    B6_SJU_JFK
# 2                                  15.000000    UA_SJU_EWR
# 3                                   5.833333    DL_DEN_ATL
# 4                                   2.000000    NK_PBG_FLL
#
#   AIRLINE_FLIGHT_NUMBER_ROUTE  AIRLINE_ROUTE_DELAY_REDUCTION_1_HOURS_MEAN  \
# 0              NK_647_IAG_FLL                                         NaN
# 1             B6_1204_SJU_JFK                                        10.0
# 2             UA_1261_SJU_EWR                                         NaN
# 3             DL_1214_DEN_ATL                                         NaN
# 4              NK_451_PBG_FLL                                         NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_5_HOURS_MEAN  \
# 0                                         NaN
# 1                                         8.5
# 2                                       -24.0
# 3                                         8.0
# 4                                         NaN
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                    16.000000
# 1                                    15.875000
# 2                                     2.333333
# 3                                    10.750000
# 4                                    18.000000
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN  \
# 0                                               16.0
# 1                                               13.0
# 2                                                NaN
# 3                                               14.0
# 4                                               18.0
#
#    DESTINATION_AIRPORT_TAXI_IN_1_HOURS_MEAN  \
# 0                                       4.0
# 1                                      10.0
# 2                                       6.6
# 3                                       NaN
# 4                                       4.0
#
#    DESTINATION_AIRPORT_TAXI_IN_5_HOURS_MEAN  \
# 0                                  4.410714
# 1                                 11.514286
# 2                                 10.105882
# 3                                 11.244186
# 4                                  4.448276
#
#    DESTINATION_AIRPORT_TAXI_IN_24_HOURS_MEAN  \
# 0                                   5.298805
# 1                                   9.677193
# 2                                   9.464832
# 3                                   8.293680
# 4                                   5.304000
#
#    PERC_OF_INCREASED_DEL_ORIGIN_AIRPORT  \
# 0                              0.375000
# 1                              0.307278
# 2                              0.307278
# 3                              0.275941
# 4                              0.356322
#
#    PERC_OF_INCREASED_DEL_DESTINATION_AIRPORT  PERC_OF_INCREASED_DEL_AIRLINE  \
# 0                                   0.258135                       0.363750
# 1                                   0.337974                       0.336859
# 2                                   0.279543                       0.216393
# 3                                   0.254317                       0.222840
# 4                                   0.258135                       0.363750
#
#    PERC_OF_INCREASED_DEL_ROUTE_STATES  PERC_OF_INCREASED_DEL_ROUTE  \
# 0                            0.308834                     0.365854
# 1                            0.367756                     0.366125
# 2                            0.301408                     0.300341
# 3                            0.209451                     0.212521
# 4                            0.308834                     0.356322
#
#    PERC_OF_INCREASED_DEL_TAIL_NUMBER  \
# 0                           0.326648
# 1                           0.355556
# 2                           0.232227
# 3                           0.194373
# 4                           0.367847
#
#    PERC_OF_INCREASED_DEL_SCHEDULED_DEPARTURE_HH  \
# 0                                      0.377301
# 1                                      0.377837
# 2                                      0.346747
# 3                                      0.346747
# 4                                      0.377837
#
#    PERC_OF_INCREASED_DEL_SCHEDULED_ARRIVAL_HH  \
# 0                                    0.304152
# 1                                    0.304152
# 2                                    0.304152
# 3                                    0.304152
# 4                                    0.304152
#
#    PERC_OF_INCREASED_DEL_AIRLINE_ROUTE  \
# 0                             0.365854
# 1                             0.352840
# 2                             0.307692
# 3                             0.173841
# 4                             0.356322
#
#    PERC_OF_INCREASED_DEL_AIRLINE_FLIGHT_NUMBER_ROUTE  \
# 0                                           0.365854
# 1                                           0.490909
# 2                                                NaN
# 3                                           0.103448
# 4                                           0.356322
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_1_MEAN  \
# 0                                               16.0
# 1                                               13.0
# 2                                                NaN
# 3                                               14.0
# 4                                               18.0
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_3_MEAN  \
# 0                                          14.000000
# 1                                          14.333333
# 2                                                NaN
# 3                                          11.333333
# 4                                          14.666667
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_7_MEAN  \
# 0                                           4.571429
# 1                                          -3.714286
# 2                                                NaN
# 3                                           9.714286
# 4                                           0.571429
#
#    ORIGIN_AIRPORT_TAXI_OUT_1_HOURS_MEAN  ORIGIN_AIRPORT_TAXI_OUT_5_HOURS_MEAN  \
# 0                                   NaN                                   NaN
# 1                             10.000000                             12.727273
# 2                             10.000000                             12.727273
# 3                              9.272727                             13.202454
# 4                                   NaN                                   NaN
#
#    ORIGIN_AIRPORT_TAXI_OUT_24_HOURS_MEAN  \
# 0                              11.000000
# 1                              13.746479
# 2                              13.763889
# 3                              13.527919
# 4                              13.000000
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_1_MEAN  \
# 0                                                5.0
# 1                                               10.0
# 2                                                NaN
# 3                                                5.0
# 4                                                8.0
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_3_MEAN  \
# 0                                           7.333333
# 1                                           8.000000
# 2                                                NaN
# 3                                           5.333333
# 4                                           9.000000
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_7_MEAN  \
# 0                                           8.857143
# 1                                           9.285714
# 2                                                NaN
# 3                                           6.000000
# 4                                          10.571429
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_1_MEAN  \
# 0                                               11.0
# 1                                               11.0
# 2                                                NaN
# 3                                               11.0
# 4                                               13.0
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_3_MEAN  \
# 0                                          10.333333
# 1                                          11.666667
# 2                                                NaN
# 3                                          12.666667
# 4                                          11.000000
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_7_MEAN  \
# 0                                           9.142857
# 1                                          16.000000
# 2                                                NaN
# 3                                          13.714286
# 4                                          13.142857
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_1_MEAN  \
# 0                                        -8.0
# 1                                        14.0
# 2                                        15.0
# 3                                         4.0
# 4                                         0.0
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_3_MEAN  \
# 0                                    4.666667
# 1                                   16.333333
# 2                                    7.666667
# 3                                    7.333333
# 4                                    2.000000
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_7_MEAN  \
# 0                                    2.285714
# 1                                   17.428571
# 2                                    9.428571
# 3                                    6.142857
# 4                                    3.428571
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                               NaN
# 1                                         11.288583
# 2                                         11.288583
# 3                                         -3.743105
# 4                                               NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                          13.127885
# 1                                           0.026126
# 2                                           1.251773
# 3                                                NaN
# 4                                          12.294552
#
#    AIRLINE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                   1.833765
# 1                                   7.945688
# 2                                   2.399367
# 3                                  -4.965448
# 4                                   0.955559
#
#    ROUTE_STATES_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                       13.889732
# 1                                       12.378158
# 2                                             NaN
# 3                                             NaN
# 4                                       13.056398
#
#    ROUTE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                      NaN
# 1                                12.274166
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                      -9.862464
# 1                                            NaN
# 2                                       7.023697
# 3                                            NaN
# 4                                      -1.433243
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_1_HOURS_MEAN_DIFF  \
# 0                                              NaN
# 1                                         6.394148
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_1_HOURS_MEAN_DIFF  \
# 0                                      -2.257000
# 1                                       0.130555
# 2                                      -3.450774
# 3                                            NaN
# 4                                      -2.257000
#
#    ORIGIN_AIRPORT_TAXI_OUT_1_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                  -3.911217
# 2                                  -3.911217
# 3                                  -7.512678
# 4                                        NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                               NaN
# 1                                         -7.211417
# 2                                         -7.211417
# 3                                          1.215623
# 4                                               NaN
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                           6.151695
# 1                                           3.100152
# 2                                          -9.536462
# 3                                          -3.268542
# 4                                           5.984207
#
#    AIRLINE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                   2.695579
# 1                                   4.604507
# 2                                  -0.014696
# 3                                  -2.961137
# 4                                   2.270756
#
#    ROUTE_STATES_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                       11.291692
# 1                                        2.378158
# 2                                      -16.857746
# 3                                       -1.479566
# 4                                       10.889732
#
#    ROUTE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                      NaN
# 1                                 2.274166
# 2                               -16.602389
# 3                                -1.540362
# 4                                      NaN
#
#    TAIL_NUMBER_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                      -9.862464
# 1                                      12.029630
# 2                                       7.023697
# 3                                      -3.309463
# 4                                      -0.433243
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_5_HOURS_MEAN_DIFF  \
# 0                                              NaN
# 1                                         4.894148
# 2                                       -29.553846
# 3                                        -2.705298
# 4                                              NaN
#
#    DESTINATION_AIRPORT_TAXI_IN_5_HOURS_MEAN_DIFF  \
# 0                                      -1.846285
# 1                                       1.644840
# 2                                       0.055108
# 3                                       2.507256
# 4                                      -1.808724
#
#    ORIGIN_AIRPORT_TAXI_OUT_5_HOURS_MEAN_DIFF  \
# 0                                        NaN
# 1                                  -1.183944
# 2                                  -1.183944
# 3                                  -3.582951
# 4                                        NaN
#
#    ORIGIN_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                          16.135417
# 1                                          -2.957896
# 2                                          -2.766973
# 3                                           2.561309
# 4                                          14.321839
#
#    DESTINATION_AIRPORT_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                           8.224831
# 1                                           2.413685
# 2                                          -3.019787
# 3                                           2.470781
# 4                                           8.198552
#
#    AIRLINE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                    2.113765
# 1                                    4.659783
# 2                                    1.162079
# 3                                    0.060259
# 4                                    2.064938
#
#    ROUTE_STATES_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                        10.891477
# 1                                        11.172275
# 2                                        -0.357746
# 3                                         0.020434
# 4                                        10.866925
#
#    ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                 16.036585
# 1                                 10.440833
# 2                                 -3.102389
# 3                                 -0.452127
# 4                                 14.321839
#
#    TAIL_NUMBER_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                        0.637536
# 1                                        4.529630
# 2                                        7.023697
# 3                                       -1.476130
# 4                                        0.566757
#
#    AIRLINE_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                         16.036585
# 1                                         12.269148
# 2                                         -3.220513
# 3                                          0.044702
# 4                                         14.321839
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_24_HOURS_MEAN_DIFF  \
# 0                                          16.036585
# 1                                          14.363636
# 2                                                NaN
# 3                                           6.310345
# 4                                          14.321839
#
#    DESTINATION_AIRPORT_TAXI_IN_24_HOURS_MEAN_DIFF  \
# 0                                       -0.958195
# 1                                       -0.192252
# 2                                       -0.585942
# 3                                       -0.443250
# 4                                       -0.953000
#
#    ORIGIN_AIRPORT_TAXI_OUT_24_HOURS_MEAN_DIFF  \
# 0                                   -4.072917
# 1                                   -0.164738
# 2                                   -0.147328
# 3                                   -3.257487
# 4                                   -2.597701
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_1_MEAN_DIFF  \
# 0                                          16.036585
# 1                                          14.363636
# 2                                                NaN
# 3                                           6.310345
# 4                                          14.321839
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_1_MEAN_DIFF  \
# 0                                          -6.890244
# 1                                           1.363636
# 2                                                NaN
# 3                                          -1.586207
# 4                                          -0.574713
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_1_MEAN_DIFF  \
# 0                                          -4.731707
# 1                                          -2.418182
# 2                                                NaN
# 3                                          -4.931034
# 4                                          -2.597701
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_1_MEAN_DIFF  \
# 0                                        -9.862464
# 1                                        12.029630
# 2                                         7.023697
# 3                                        -3.309463
# 4                                        -1.433243
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_3_MEAN_DIFF  \
# 0                                          14.036585
# 1                                          15.696970
# 2                                                NaN
# 3                                           3.643678
# 4                                          10.988506
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_3_MEAN_DIFF  \
# 0                                          -4.556911
# 1                                          -0.636364
# 2                                                NaN
# 3                                          -1.252874
# 4                                           0.425287
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_3_MEAN_DIFF  \
# 0                                          -5.398374
# 1                                          -1.751515
# 2                                                NaN
# 3                                          -3.264368
# 4                                          -4.597701
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_3_MEAN_DIFF  \
# 0                                         2.804202
# 1                                        14.362963
# 2                                        -0.309637
# 3                                         0.023870
# 4                                         0.566757
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_DELAY_REDUCTION_ROLLING_7_MEAN_DIFF  \
# 0                                           4.608014
# 1                                          -2.350649
# 2                                                NaN
# 3                                           2.024631
# 4                                          -3.106732
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_IN_ROLLING_7_MEAN_DIFF  \
# 0                                          -3.033101
# 1                                           0.649351
# 2                                                NaN
# 3                                          -0.586207
# 4                                           1.996716
#
#    AIRLINE_FLIGHT_NUMBER_ROUTE_TAXI_OUT_ROLLING_7_MEAN_DIFF  \
# 0                                          -6.588850
# 1                                           2.581818
# 2                                                NaN
# 3                                          -2.216749
# 4                                          -2.454844
#
#    TAIL_NUMBER_DELAY_REDUCTION_ROLLING_7_MEAN_DIFF
# 0                                         0.423250
# 1                                        15.458201
# 2                                         1.452268
# 3                                        -1.166606
# 4                                         1.995329

# %%
train.to_pickle('train.pkl')
test.to_pickle('test.pkl')
